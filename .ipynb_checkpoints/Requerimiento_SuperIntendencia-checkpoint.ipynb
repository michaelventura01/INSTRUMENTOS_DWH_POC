# %% [markdown]
# ## Extraccion con el API Alpha Vantage

# %% [markdown]
# ### Cargando Dependencias

# %%
import requests
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import json
import datetime
from datetime import date
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, StructField, StringType, IntegerType


# spark = SparkSession.builder \
#     .appName("Instrumentos Session") \
#     .config("spark.ui.port", "4050") \
#     .getOrCreate()

# %% [markdown]
# ### Funciones de Extraccion

# %%
from extraccion.extraccion_api import *

# %%
simbolos_df = obtener_simbolos()

# %% [markdown]
# #### logica de extraccion

# %%
API_KEY = 'YDMGB3KH33ZX10HA'
error_logs = []

def get_errors():
    return error_logs

def remove_error_logs():
    error_logs = []

def add_error_logs(error):
    error_logs.append(error)

def get_alpha_vantage_data(function, symbol):
  url = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}&apikey={API_KEY}'
  try:
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()

    if "Error Message" in data:
      add_error_logs(f"Error para el símbolo {symbol}: {data['Error Message']}")
      return None

    return data

  except requests.exceptions.RequestException as e:
    add_error_logs(f"Error al realizar la solicitud a Alpha Vantage para {symbol}: {e}")
    return None
  except ValueError as e:
    add_error_logs(f"Error al procesar la respuesta JSON {symbol}")
    return None

def get_overview_data_for_multiple_symbols(symbols):
  overview_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('INCOME_STATEMENT', symbol)
    if data:
      overview_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return overview_data

def get_income_statement_data_for_multiple_symbols(symbols):
  overview_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('OVERVIEW', symbol)
    if data:
      overview_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return overview_data


def get_balance_sheet_data_for_multiple_symbols(symbols):
  balance_sheet_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('BALANCE_SHEET', symbol)
    if data:
      balance_sheet_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return balance_sheet_data

def get_cash_flow_data_for_multiple_symbols(symbols):
  cash_flow_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('CASH_FLOW', symbol)
    if data:
      cash_flow_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return cash_flow_data

def get_cpi_data_for_multiple_symbols(symbols):
  cpi_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('CPI', symbol)
    if data:
      cpi_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return cpi_data


def get_inflation_data_for_multiple_symbols(symbols):
  inflation_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('INFLATION', symbol)
    if data:
      inflation_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return inflation_data

def get_retail_sales_data_for_multiple_symbols(symbols):
  retail_sales_data = []

  for symbol in symbols:
    data = get_alpha_vantage_data('RETAIL_SALES', symbol)
    if data:
      retail_sales_data.append({symbol: data})
    else:
      add_error_logs(f"No se pudieron obtener datos para {symbol}" )
  return retail_sales_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[793], line 1
# ----> 1 obtener_simbolos()
#       2 add_error_logs("")
#
# NameError: name 'obtener_simbolos' is not defined

# %% [markdown]
# ### Extraccion de Data

# %%
symbols = simbolos_df['codigo'].head(3)

# %%
overview_data = get_overview_data_for_multiple_symbols(symbols)
income_statement_data = get_overview_data_for_multiple_symbols(symbols)
balance_sheet_data = get_balance_sheet_data_for_multiple_symbols(symbols)
retail_sales_data = get_retail_sales_data_for_multiple_symbols(symbols)
cash_flow_data = get_cash_flow_data_for_multiple_symbols(symbols)
cpi_data = get_cpi_data_for_multiple_symbols(symbols)
inflation_data = get_inflation_data_for_multiple_symbols(symbols)

# %% [markdown]
# ### Preparacion de Data

# %%
overview_df = pd.DataFrame(overview_data)
income_statement_df = pd.DataFrame(income_statement_data)
balance_sheet_df  = pd.DataFrame(balance_sheet_data)
retail_sales_df = pd.DataFrame(retail_sales_data)
cash_flow_df = pd.DataFrame(cash_flow_data)
cpi_df = pd.DataFrame(cpi_data)
inflation_df = pd.DataFrame(inflation_data)

# %% [markdown]
# ### Validando Errores

# %%
error_logs
# Out:
# []

# %% [markdown]
# ### Preparando Overview

# %%
overviews_df = pd.DataFrame()

for symbol in symbols:
  for overview in overview_df[symbol]:
    if(pd.notna(overview)):
      if isinstance(overview, dict) or isinstance(overview, list):
        if('annualReports' in overview):
          overviewsdf = pd.DataFrame(overview['annualReports'])
          overviewsdf['Symbol'] = overview['symbol']
          overviewsdf['loadDate'] = date.today()
          overviews_df = pd.concat([overviews_df,overviewsdf], ignore_index=True)

overviews_df[overviews_df['Symbol']== 'JPM'].head()
# Out:
#   fiscalDateEnding reportedCurrency  grossProfit  totalRevenue costOfRevenue  \
# 0       2023-12-31              USD  61612000000  158104000000   96492000000
# 1       2022-12-31              USD  46166000000  128695000000   82529000000
# 2       2021-12-31              USD  59562000000  121649000000   62087000000
# 3       2020-12-31              USD  35407000000  119951000000   84136000000
# 4       2019-12-31              USD  44545000000  115720000000   71082000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0                -9282000000     29815000000                     18427000000
# 1                10174000000     17761000000                     17965000000
# 2                 9814000000     31829000000                     17493000000
# 3                 8464000000      8580000000                     17263000000
# 4                 8533000000     18051000000                     17722000000
#
# ...

# %%
# overviews_df.columns
print("create table staging.stg_overview( \nid serial primary key")
for column in overviews_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_overview(
# id serial primary key
# ,fiscalDateEnding varchar(250)
# ,reportedCurrency varchar(250)
# ,grossProfit varchar(250)
# ,totalRevenue varchar(250)
# ,costOfRevenue varchar(250)
# ,costofGoodsAndServicesSold varchar(250)
# ,operatingIncome varchar(250)
# ,sellingGeneralAndAdministrative varchar(250)
# ,researchAndDevelopment varchar(250)
# ,operatingExpenses varchar(250)
# ,investmentIncomeNet varchar(250)
# ,netInterestIncome varchar(250)
# ,interestIncome varchar(250)
# ,interestExpense varchar(250)
# ,nonInterestIncome varchar(250)
# ,otherNonOperatingIncome varchar(250)
# ,depreciation varchar(250)
# ,depreciationAndAmortization varchar(250)
# ,incomeBeforeTax varchar(250)
# ,incomeTaxExpense varchar(250)
# ,interestAndDebtExpense varchar(250)
# ,netIncomeFromContinuingOperations varchar(250)
# ,comprehensiveIncomeNetOfTax varchar(250)
# ,ebit varchar(250)
# ,ebitda varchar(250)
# ,netIncome varchar(250)
# ,Symbol varchar(250)
# ...

# %%
overviews_df['reportedCurrency'].unique()
# Out:
# array(['USD', 'GBP'], dtype=object)

# %% [markdown]
# ### Preparando Income Statement

# %%
incomestatement_annualReports_df = pd.DataFrame()
for symbol in symbols:
  for incomestatement in income_statement_df[symbol]:
    if(pd.notna(incomestatement)):
      if('annualReports' in incomestatement):
        incomestatement_df = pd.DataFrame(incomestatement['annualReports'])
        incomestatement_df['Symbol'] = incomestatement['symbol']
        incomestatement_df['loadDate'] = date.today()
        incomestatement_annualReports_df = pd.concat([incomestatement_annualReports_df,incomestatement_df], ignore_index=True)


incomestatement_annualReports_df[incomestatement_annualReports_df['Symbol']== 'BCS'].head()
# Out:
#    fiscalDateEnding reportedCurrency  grossProfit totalRevenue costOfRevenue  \
# 15       2024-12-31              USD  26230000000  26230000000          None
# 16       2023-12-31              GBP  51336000000  23497000000  -27839000000
# 17       2022-12-31              GBP  24956000000  24956000000          None
# 18       2021-12-31              GBP  21940000000  21940000000          None
# 19       2020-12-31              GBP  21766000000  21766000000          None
#
#    costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 15                       None            None                      2121000000
# 16               -27839000000      7418000000                      2017000000
# 17                       None     15491000000                      1770000000
# 18                       None      8367000000                      1568000000
# 19                       None      2987000000                      5636000000
#
# ...

# %%
print("create table staging.stg_income_statement( \nid serial primary key")
for column in incomestatement_annualReports_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_income_statement(
# id serial primary key
# ,fiscalDateEnding varchar(250)
# ,reportedCurrency varchar(250)
# ,grossProfit varchar(250)
# ,totalRevenue varchar(250)
# ,costOfRevenue varchar(250)
# ,costofGoodsAndServicesSold varchar(250)
# ,operatingIncome varchar(250)
# ,sellingGeneralAndAdministrative varchar(250)
# ,researchAndDevelopment varchar(250)
# ,operatingExpenses varchar(250)
# ,investmentIncomeNet varchar(250)
# ,netInterestIncome varchar(250)
# ,interestIncome varchar(250)
# ,interestExpense varchar(250)
# ,nonInterestIncome varchar(250)
# ,otherNonOperatingIncome varchar(250)
# ,depreciation varchar(250)
# ,depreciationAndAmortization varchar(250)
# ,incomeBeforeTax varchar(250)
# ,incomeTaxExpense varchar(250)
# ,interestAndDebtExpense varchar(250)
# ,netIncomeFromContinuingOperations varchar(250)
# ,comprehensiveIncomeNetOfTax varchar(250)
# ,ebit varchar(250)
# ,ebitda varchar(250)
# ,netIncome varchar(250)
# ,Symbol varchar(250)
# ...

# %%
incomestatement_annualReports_df['reportedCurrency'].unique()
# Out:
# array(['USD', 'GBP'], dtype=object)

# %% [markdown]
# ### Preparacion de Balance

# %%
balance_annualReports_df = pd.DataFrame()

for symbol in symbols:
  for balance in balance_sheet_df[symbol]:
    if(pd.notna(balance)):
      if('annualReports' in balance):
        annualReports_df = pd.DataFrame(balance['annualReports'])
        annualReports_df['Symbol'] = balance['symbol']
        annualReports_df['loadDate'] = date.today()
        balance_annualReports_df = pd.concat([balance_annualReports_df,annualReports_df], ignore_index=True)

balance_annualReports_df[balance_annualReports_df['Symbol']== 'BCS'].head()
# Out:
#    fiscalDateEnding reportedCurrency    totalAssets totalCurrentAssets  \
# 16       2024-12-31              GBP  1518202000000       210184000000
# 17       2023-12-31              GBP  1477487000000       510843000000
# 18       2022-12-31              GBP  1513699000000       256351000000
# 19       2021-12-31              GBP  1384285000000       238574000000
# 20       2020-12-31              GBP  1349514000000       191127000000
#
#    cashAndCashEquivalentsAtCarryingValue cashAndShortTermInvestments  \
# 16                          210184000000                210184000000
# 17                          224634000000                224634000000
# 18                          256351000000                256351000000
# 19                          238574000000                238574000000
# 20                          191127000000                191127000000
#
#    inventory currentNetReceivables totalNonCurrentAssets  \
# 16      None                  None         1308018000000
# ...

# %%
print("create table staging.stg_balance( \nid serial primary key")
for column in balance_annualReports_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_balance(
# id serial primary key
# ,fiscalDateEnding varchar(250)
# ,reportedCurrency varchar(250)
# ,totalAssets varchar(250)
# ,totalCurrentAssets varchar(250)
# ,cashAndCashEquivalentsAtCarryingValue varchar(250)
# ,cashAndShortTermInvestments varchar(250)
# ,inventory varchar(250)
# ,currentNetReceivables varchar(250)
# ,totalNonCurrentAssets varchar(250)
# ,propertyPlantEquipment varchar(250)
# ,accumulatedDepreciationAmortizationPPE varchar(250)
# ,intangibleAssets varchar(250)
# ,intangibleAssetsExcludingGoodwill varchar(250)
# ,goodwill varchar(250)
# ,investments varchar(250)
# ,longTermInvestments varchar(250)
# ,shortTermInvestments varchar(250)
# ,otherCurrentAssets varchar(250)
# ,otherNonCurrentAssets varchar(250)
# ,totalLiabilities varchar(250)
# ,totalCurrentLiabilities varchar(250)
# ,currentAccountsPayable varchar(250)
# ,deferredRevenue varchar(250)
# ,currentDebt varchar(250)
# ,shortTermDebt varchar(250)
# ...

# %%
balance_annualReports_df['reportedCurrency'].unique()
# Out:
# array(['USD', 'GBP'], dtype=object)

# %% [markdown]
# ### Preparando Retail

# %%
retaildata_df = pd.DataFrame()

for symbol in symbols:
  for retail in retail_sales_df[symbol]:
    if(pd.notna(retail)):
      if('data' in retail):
        retail_df = pd.DataFrame(retail['data'])
        retail_df['name'] = retail['name']
        retail_df['interval'] = retail['interval']
        retail_df['unit'] = retail['unit']
        retail_df['Symbol'] = symbol
        retail_df['loadDate'] = date.today()
        retaildata_df = pd.concat([retaildata_df,retail_df], ignore_index=True)

retaildata_df[retaildata_df['Symbol']== 'JPM'].head()
# Out:
#          date     value                                name interval  \
# 0  2025-01-01  577230.0  Advance Retail Sales: Retail Trade  monthly
# 1  2024-12-01  702255.0  Advance Retail Sales: Retail Trade  monthly
# 2  2024-11-01  641949.0  Advance Retail Sales: Retail Trade  monthly
# 3  2024-10-01  633013.0  Advance Retail Sales: Retail Trade  monthly
# 4  2024-09-01  589777.0  Advance Retail Sales: Retail Trade  monthly
#
#                   unit Symbol    loadDate
# 0  millions of dollars    JPM  2025-03-10
# 1  millions of dollars    JPM  2025-03-10
# 2  millions of dollars    JPM  2025-03-10
# 3  millions of dollars    JPM  2025-03-10
# 4  millions of dollars    JPM  2025-03-10

# %%
print("create table staging.stg_retail( \nid serial primary key")
for column in retaildata_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_retail(
# id serial primary key
# ,date varchar(250)
# ,value varchar(250)
# ,name varchar(250)
# ,interval varchar(250)
# ,unit varchar(250)
# ,Symbol varchar(250)
# ,loadDate varchar(250)
# );

# %%
retaildata_df['unit'].unique()
# Out:
# array(['millions of dollars'], dtype=object)

# %% [markdown]
# ### Preparando CashFlow

# %%
cashflow_annualreport_df = pd.DataFrame()

for symbol in symbols:
  for cashflow in cash_flow_df[symbol]:
    if(pd.notna(cashflow)):
      if('annualReports' in cashflow):
        cashflow_df = pd.DataFrame(cashflow['annualReports'])
        cashflow_df['Symbol'] = symbol
        cashflow_df['loadDate'] = date.today()
        cashflow_annualreport_df = pd.concat([cashflow_annualreport_df,cashflow_df], ignore_index=True)

cashflow_annualreport_df[cashflow_annualreport_df['Symbol']== 'JPM'].head()
# Out:
#   fiscalDateEnding reportedCurrency operatingCashflow  \
# 0       2023-12-31              USD       12974000000
# 1       2022-12-31              USD      107119000000
# 2       2021-12-31              USD       78084000000
# 3       2020-12-31              USD      -79910000000
# 4       2019-12-31              USD        4092000000
#
#   paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                    78776000000                            None
# 1                    24756000000                            None
# 2                     6798000000                            None
# 3                    14703000000                            None
# 4                    31490000000                            None
#
#   changeInOperatingLiabilities changeInOperatingAssets  \
# 0                   5315000000            171268000000
# 1                  11170000000            163295000000
# 2                 -23190000000            319534000000
# ...

# %%
print("create table staging.stg_cash_flow( \nid serial primary key")
for column in cashflow_annualreport_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_cash_flow(
# id serial primary key
# ,fiscalDateEnding varchar(250)
# ,reportedCurrency varchar(250)
# ,operatingCashflow varchar(250)
# ,paymentsForOperatingActivities varchar(250)
# ,proceedsFromOperatingActivities varchar(250)
# ,changeInOperatingLiabilities varchar(250)
# ,changeInOperatingAssets varchar(250)
# ,depreciationDepletionAndAmortization varchar(250)
# ,capitalExpenditures varchar(250)
# ,changeInReceivables varchar(250)
# ,changeInInventory varchar(250)
# ,profitLoss varchar(250)
# ,cashflowFromInvestment varchar(250)
# ,cashflowFromFinancing varchar(250)
# ,proceedsFromRepaymentsOfShortTermDebt varchar(250)
# ,paymentsForRepurchaseOfCommonStock varchar(250)
# ,paymentsForRepurchaseOfEquity varchar(250)
# ,paymentsForRepurchaseOfPreferredStock varchar(250)
# ,dividendPayout varchar(250)
# ,dividendPayoutCommonStock varchar(250)
# ,dividendPayoutPreferredStock varchar(250)
# ,proceedsFromIssuanceOfCommonStock varchar(250)
# ...

# %% [markdown]
# ### Preparando CPI

# %%
cpidata_df = pd.DataFrame()

for symbol in symbols:
  for cpi in cpi_df[symbol]:
    if(pd.notna(cpi)):
      if('data' in cpi):
        cpidf = pd.DataFrame(cpi['data'])
        cpidf['Symbol'] = symbol
        cpidf['name'] = cpi['name']
        cpidf['interval'] = cpi['interval']
        cpidf['unit'] = cpi['unit']
        cpidf['loadDate'] = date.today()
        cpidata_df = pd.concat([cpidata_df,cpidf], ignore_index=True)

cpidata_df[cpidata_df['Symbol']== 'JPM'].head()
# Out:
#          date    value Symbol                                          name  \
# 0  2025-01-01  317.671    JPM  Consumer Price Index for all Urban Consumers
# 1  2024-12-01  315.605    JPM  Consumer Price Index for all Urban Consumers
# 2  2024-11-01  315.493    JPM  Consumer Price Index for all Urban Consumers
# 3  2024-10-01  315.664    JPM  Consumer Price Index for all Urban Consumers
# 4  2024-09-01  315.301    JPM  Consumer Price Index for all Urban Consumers
#
#   interval                 unit    loadDate
# 0  monthly  index 1982-1984=100  2025-03-10
# 1  monthly  index 1982-1984=100  2025-03-10
# 2  monthly  index 1982-1984=100  2025-03-10
# 3  monthly  index 1982-1984=100  2025-03-10
# 4  monthly  index 1982-1984=100  2025-03-10

# %%
print("create table staging.stg_cpi( \nid serial primary key")
for column in cpidata_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_cpi(
# id serial primary key
# ,date varchar(250)
# ,value varchar(250)
# ,Symbol varchar(250)
# ,name varchar(250)
# ,interval varchar(250)
# ,unit varchar(250)
# ,loadDate varchar(250)
# );

# %% [markdown]
# ### Preparando Inflation

# %%
inflationdata_df = pd.DataFrame()

for symbol in symbols:
  for inflation in inflation_df[symbol]:
    if(pd.notna(inflation)):
      if('data' in inflation):
        inflatio_df = pd.DataFrame(inflation['data'])
        inflatio_df['Symbol'] = symbol
        inflatio_df['name'] = inflation['name']
        inflatio_df['interval'] = inflation['interval']
        inflatio_df['unit'] = inflation['unit']
        inflatio_df['loadDate'] = date.today()
        inflationdata_df = pd.concat([inflationdata_df,inflatio_df], ignore_index=True)

inflationdata_df[inflationdata_df['Symbol']== 'JPM'].head()
# Out:
#          date             value Symbol                            name  \
# 0  2023-01-01  4.11633838374488    JPM  Inflation - US Consumer Prices
# 1  2022-01-01  8.00279982052121    JPM  Inflation - US Consumer Prices
# 2  2021-01-01  4.69785886363742    JPM  Inflation - US Consumer Prices
# 3  2020-01-01  1.23358439630629    JPM  Inflation - US Consumer Prices
# 4  2019-01-01  1.81221007526021    JPM  Inflation - US Consumer Prices
#
#   interval     unit    loadDate
# 0   annual  percent  2025-03-10
# 1   annual  percent  2025-03-10
# 2   annual  percent  2025-03-10
# 3   annual  percent  2025-03-10
# 4   annual  percent  2025-03-10

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from extraccion.extraccion_data import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from extraccion.extraccion_data import *
#
# File ~\OneDrive\Documentos\PROJECTS\INSTRUMENTOS_DWH\extraccion\extraccion_data.py:1
# ----> 1 from extraccion_api import *
#       2 from dotenv import load_dotenv
#       3 import os
#
# ModuleNotFoundError: No module named 'extraccion_api'

# %% [markdown]
# ## Preparando Base de Datos

# %%
def get_conexion_string():
    return 'postgresql+psycopg2://admin:admin@localhost:5432/INSTRUMENTOS_DWH'

# %%
symbols_df

# Conexión a PostgreSQL
engine = create_engine(get_conexion_string())

# Cargar el DataFrame en la tabla de PostgreSQL
symbols_df.to_sql('simbolos', engine, index=False, if_exists='replace', schema='diccionario')  # Cambiar 'replace' por 'append' si deseas agregar a una tabla existente

print("Data cargada exitosamente.")
# Out:
# Data cargada exitosamente.

# %%
print("create table staging.stg_inflation( \nid serial primary key")
for column in inflationdata_df.columns:
 print(f',{column} varchar(250)')
print(");")
# Out:
# create table staging.stg_inflation(
# id serial primary key
# ,date varchar(250)
# ,value varchar(250)
# ,Symbol varchar(250)
# ,name varchar(250)
# ,interval varchar(250)
# ,unit varchar(250)
# ,loadDate varchar(250)
# );

# %%
def get_conexion():
    conexion = psycopg2.connect(
        host="localhost",
        dbname="INSTRUMENTOS_DWH",
        user="admin",
        password="admin"
    )
    return conexion

def truncar_tablas():
    try:
        conexion = get_conexion()
        cursor = conexion.cursor()
        
        truncate_script = ""
        for df, schema, tabla in staging_dataframes:
            truncate_script += f'truncate table {schema}.{tabla} restart identity cascade;'

        cursor.execute(truncate_script)
        conexion.commit()
    except psycopg2.Error as e:
        add_error_logs(f"Error en la operación de truncado: {e}")
        if conexion:
            conexion.rollback()
    finally:
        if cursor:
            cursor.close()
        if conexion:
            conexion.close()

def cargar_logs(cursor, conexion, schema, tabla):
    log_query = """
        INSERT INTO metadata.process_log (descripcion, etapa, fecha, entidad, estatus)
            VALUES (%s, %s, %s, %s, %s)
    """
    log_values = (f'carga de tabla {tabla}', schema, datetime.datetime.now(), tabla, 'exitoso')
    cursor.execute(log_query, log_values)

    conexion.commit() 

def cargar_log_error(cursor, conexion, schema, tabla, error):
    log_query = """
        INSERT INTO metadata.error_log (descripcion, etapa, fecha, entidad)
            VALUES (%s, %s, %s, %s)
    """
    log_values = (error, schema, datetime.datetime.now(), tabla)
    cursor.execute(log_query, log_values)

    conexion.commit() 

def cargar_staging():
    columnas = ['descripcion', 'etapa', 'fecha', 'entidad', 'estatus']
    log_results_df = pd.DataFrame(columns=columnas)
    
    try:
        conexion = get_conexion()
        cursor = conexion.cursor()

        for df, schema, tabla in staging_dataframes:
            for i, row in df.iterrows():
                columns = ', '.join(df.columns)
                values = ', '.join([f"'{str(value)}'" if value is not None else "NULL" for value in row])
                query = f"INSERT INTO {schema}.{tabla} ({columns}) VALUES ({values})"
                cursor.execute(query)
            conexion.commit()
            cargar_logs(cursor, conexion, schema, tabla)                               

        cursor.close()
        conexion.close()
        
    except Exception as e:
        add_error_logs(f"Error al cargar los DataFrames: {e}")        
        if conexion:
            conexion.rollback()
        if cursor:
            cursor.close()
        if conexion:
            conexion.close()

# %%
staging_dataframes = [
    (inflationdata_df, 'staging','stg_inflation'),
    (cpidata_df,'staging', 'stg_cpi'),
    (cashflow_annualreport_df,'staging', 'stg_cash_flow'),
    (overviews_df,'staging', 'stg_overview'),
    (incomestatement_annualReports_df,'staging', 'stg_income_statement'),
    (balance_annualReports_df,'staging', 'stg_balance'),
    (retaildata_df,'staging', 'stg_retail')    
]

# %%
inflationdata_df
# Out:
#            date             value Symbol                            name  \
# 0    2023-01-01  4.11633838374488    JPM  Inflation - US Consumer Prices
# 1    2022-01-01  8.00279982052121    JPM  Inflation - US Consumer Prices
# 2    2021-01-01  4.69785886363742    JPM  Inflation - US Consumer Prices
# 3    2020-01-01  1.23358439630629    JPM  Inflation - US Consumer Prices
# 4    2019-01-01  1.81221007526021    JPM  Inflation - US Consumer Prices
# ..          ...               ...    ...                             ...
# 123  1964-01-01  1.27891156462591    BCS  Inflation - US Consumer Prices
# 124  1963-01-01  1.23966942148753    BCS  Inflation - US Consumer Prices
# 125  1962-01-01  1.19877334820186    BCS  Inflation - US Consumer Prices
# 126  1961-01-01  1.07072414764724    BCS  Inflation - US Consumer Prices
# 127  1960-01-01  1.45797598627791    BCS  Inflation - US Consumer Prices
#
#     interval     unit    loadDate
# 0     annual  percent  2025-03-10
# ...

# %% [markdown]
# ## Preparando STAGING

# %% [markdown]
# ### Cargando Staging

# %%
truncar_tablas()
cargar_staging()

# %% [markdown]
# ## Preparando Carga DWH

# %% [markdown]
# ### Limpiando data staging

# %%
def obtener_staging(tabla):
    engine = create_engine(get_conexion_string())
    query = f'select * from staging.{tabla}'
    dataframe = pd.read_sql(query,engine)
    return dataframe

# %%
balance_stg_df = pd.DataFrame()
inflation_stg_df = pd.DataFrame()
retail_stg_df = pd.DataFrame()
income_statement_stg_df = pd.DataFrame()
overview_stg_df = pd.DataFrame()
cpi_stg_df = pd.DataFrame()
cash_flow_stg_df = pd.DataFrame()

# %%
balance_stg_df = obtener_staging('stg_balance')
cpi_stg_df = obtener_staging('stg_cpi')
cash_flow_stg_df = obtener_staging('stg_cash_flow')
overview_stg_df = obtener_staging('stg_overview') 
income_statement_stg_df = obtener_staging('stg_income_statement')
inflation_stg_df = obtener_staging('stg_inflation')
retail_stg_df = obtener_staging('stg_retail')

# %%
retail_stg_df.dtypes
# Out:
# id           int64
# date        object
# value       object
# name        object
# interval    object
# unit        object
# symbol      object
# loaddate    object
# dtype: object

# %% [markdown]
# ### validar balance

# %%
balance_stg_df = balance_stg_df.replace('None','0')
if(balance_stg_df.dtypes['totalassets'] == 'O'):
    balance_stg_df['totalassets']  = pd.to_numeric(balance_stg_df['totalassets'], errors='coerce')
if(balance_stg_df.dtypes['totalcurrentassets'] == 'O'):
    balance_stg_df['totalcurrentassets']  = pd.to_numeric(balance_stg_df['totalcurrentassets'], errors='coerce')
if(balance_stg_df.dtypes['cashandcashequivalentsatcarryingvalue'] == 'O'):
    balance_stg_df['cashandcashequivalentsatcarryingvalue']  = pd.to_numeric(balance_stg_df['cashandcashequivalentsatcarryingvalue'], errors='coerce')
if(balance_stg_df.dtypes['cashandshortterminvestments'] == 'O'):
    balance_stg_df['cashandshortterminvestments']  = pd.to_numeric(balance_stg_df['cashandshortterminvestments'], errors='coerce')
if(balance_stg_df.dtypes['inventory'] == 'O'):
    balance_stg_df['inventory']  = pd.to_numeric(balance_stg_df['inventory'], errors='coerce')
if(balance_stg_df.dtypes['currentnetreceivables'] == 'O'):
    balance_stg_df['currentnetreceivables']  = pd.to_numeric(balance_stg_df['currentnetreceivables'], errors='coerce')
if(balance_stg_df.dtypes['totalnoncurrentassets'] == 'O'):
    balance_stg_df['totalnoncurrentassets']  = pd.to_numeric(balance_stg_df['totalnoncurrentassets'], errors='coerce')
if(balance_stg_df.dtypes['propertyplantequipment'] == 'O'):
    balance_stg_df['propertyplantequipment']  = pd.to_numeric(balance_stg_df['propertyplantequipment'], errors='coerce')
if(balance_stg_df.dtypes['accumulateddepreciationamortizationppe'] == 'O'):
    balance_stg_df['accumulateddepreciationamortizationppe']  = pd.to_numeric(balance_stg_df['accumulateddepreciationamortizationppe'], errors='coerce')
if(balance_stg_df.dtypes['intangibleassets'] == 'O'):
    balance_stg_df['intangibleassets']  = pd.to_numeric(balance_stg_df['intangibleassets'], errors='coerce')
if(balance_stg_df.dtypes['intangibleassetsexcludinggoodwill'] == 'O'):
    balance_stg_df['intangibleassetsexcludinggoodwill']  = pd.to_numeric(balance_stg_df['intangibleassetsexcludinggoodwill'], errors='coerce')
if(balance_stg_df.dtypes['goodwill'] == 'O'):
    balance_stg_df['goodwill']  = pd.to_numeric(balance_stg_df['goodwill'], errors='coerce')
if(balance_stg_df.dtypes['investments'] == 'O'):
    balance_stg_df['investments']  = pd.to_numeric(balance_stg_df['investments'], errors='coerce')
if(balance_stg_df.dtypes['longterminvestments'] == 'O'):
    balance_stg_df['longterminvestments']  = pd.to_numeric(balance_stg_df['longterminvestments'], errors='coerce')
if(balance_stg_df.dtypes['shortterminvestments'] == 'O'):
    balance_stg_df['shortterminvestments']  = pd.to_numeric(balance_stg_df['shortterminvestments'], errors='coerce')
if(balance_stg_df.dtypes['othercurrentassets'] == 'O'):
    balance_stg_df['othercurrentassets']  = pd.to_numeric(balance_stg_df['othercurrentassets'], errors='coerce')
if(balance_stg_df.dtypes['othernoncurrentassets'] == 'O'):
    balance_stg_df['othernoncurrentassets']  = pd.to_numeric(balance_stg_df['othernoncurrentassets'], errors='coerce')
if(balance_stg_df.dtypes['totalliabilities'] == 'O'):
    balance_stg_df['totalliabilities']  = pd.to_numeric(balance_stg_df['totalliabilities'], errors='coerce')
if(balance_stg_df.dtypes['totalcurrentliabilities'] == 'O'):
    balance_stg_df['totalcurrentliabilities']  = pd.to_numeric(balance_stg_df['totalcurrentliabilities'], errors='coerce')
if(balance_stg_df.dtypes['currentaccountspayable'] == 'O'):
    balance_stg_df['currentaccountspayable']  = pd.to_numeric(balance_stg_df['currentaccountspayable'], errors='coerce')
if(balance_stg_df.dtypes['deferredrevenue'] == 'O'):
    balance_stg_df['deferredrevenue']  = pd.to_numeric(balance_stg_df['deferredrevenue'], errors='coerce')
if(balance_stg_df.dtypes['currentdebt'] == 'O'):
    balance_stg_df['currentdebt']  = pd.to_numeric(balance_stg_df['currentdebt'], errors='coerce')
if(balance_stg_df.dtypes['shorttermdebt'] == 'O'):
    balance_stg_df['shorttermdebt']  = pd.to_numeric(balance_stg_df['shorttermdebt'], errors='coerce')
if(balance_stg_df.dtypes['totalnoncurrentliabilities'] == 'O'):
    balance_stg_df['totalnoncurrentliabilities']  = pd.to_numeric(balance_stg_df['totalnoncurrentliabilities'], errors='coerce')
if(balance_stg_df.dtypes['capitalleaseobligations'] == 'O'):
    balance_stg_df['capitalleaseobligations']  = pd.to_numeric(balance_stg_df['capitalleaseobligations'], errors='coerce')
if(balance_stg_df.dtypes['longtermdebt'] == 'O'):
    balance_stg_df['longtermdebt']  = pd.to_numeric(balance_stg_df['longtermdebt'], errors='coerce')
if(balance_stg_df.dtypes['currentlongtermdebt'] == 'O'):
    balance_stg_df['currentlongtermdebt']  = pd.to_numeric(balance_stg_df['currentlongtermdebt'], errors='coerce')
if(balance_stg_df.dtypes['longtermdebtnoncurrent'] == 'O'):
    balance_stg_df['longtermdebtnoncurrent']  = pd.to_numeric(balance_stg_df['longtermdebtnoncurrent'], errors='coerce')
if(balance_stg_df.dtypes['shortlongtermdebttotal'] == 'O'):
    balance_stg_df['shortlongtermdebttotal']  = pd.to_numeric(balance_stg_df['shortlongtermdebttotal'], errors='coerce')
if(balance_stg_df.dtypes['othercurrentliabilities'] == 'O'):
    balance_stg_df['othercurrentliabilities']  = pd.to_numeric(balance_stg_df['othercurrentliabilities'], errors='coerce')
if(balance_stg_df.dtypes['othernoncurrentliabilities'] == 'O'):
    balance_stg_df['othernoncurrentliabilities']  = pd.to_numeric(balance_stg_df['othernoncurrentliabilities'], errors='coerce')
if(balance_stg_df.dtypes['totalshareholderequity'] == 'O'):
    balance_stg_df['totalshareholderequity']  = pd.to_numeric(balance_stg_df['totalshareholderequity'], errors='coerce')
if(balance_stg_df.dtypes['treasurystock'] == 'O'):
    balance_stg_df['treasurystock']  = pd.to_numeric(balance_stg_df['treasurystock'], errors='coerce')
if(balance_stg_df.dtypes['retainedearnings'] == 'O'):
    balance_stg_df['retainedearnings']  = pd.to_numeric(balance_stg_df['retainedearnings'], errors='coerce')
if(balance_stg_df.dtypes['commonstock'] == 'O'):
    balance_stg_df['commonstock']  = pd.to_numeric(balance_stg_df['commonstock'], errors='coerce')
if(balance_stg_df.dtypes['commonstocksharesoutstanding'] == 'O'):
    balance_stg_df['commonstocksharesoutstanding']  = pd.to_numeric(balance_stg_df['commonstocksharesoutstanding'], errors='coerce')

# %% [markdown]
# ### validar cpi

# %%
cpi_stg_df = cpi_stg_df.replace('None','0')
if(cpi_stg_df.dtypes['value'] == 'O'):
    cpi_stg_df['value']  = pd.to_numeric(cpi_stg_df['value'], errors='coerce')

# %% [markdown]
# ### validar cash flow

# %%
cash_flow_stg_df = cash_flow_stg_df.replace('None','0')
if(cash_flow_stg_df.dtypes['operatingcashflow'] == 'O'):
    cash_flow_stg_df['operatingcashflow'] = pd.to_numeric(cash_flow_stg_df['operatingcashflow'], errors='coerce')
if(cash_flow_stg_df.dtypes['paymentsforoperatingactivities'] == 'O'):
    cash_flow_stg_df['totalassets'] = pd.to_numeric(cash_flow_stg_df['paymentsforoperatingactivities'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromoperatingactivities'] == 'O'):
    cash_flow_stg_df['proceedsfromoperatingactivities'] = pd.to_numeric(cash_flow_stg_df['proceedsfromoperatingactivities'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeinoperatingliabilities'] == 'O'):
    cash_flow_stg_df['changeinoperatingliabilities'] = pd.to_numeric(cash_flow_stg_df['changeinoperatingliabilities'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeinoperatingassets'] == 'O'):
    cash_flow_stg_df['changeinoperatingassets'] = pd.to_numeric(cash_flow_stg_df['changeinoperatingassets'], errors='coerce')
if(cash_flow_stg_df.dtypes['depreciationdepletionandamortization'] == 'O'):
    cash_flow_stg_df['depreciationdepletionandamortization'] = pd.to_numeric(cash_flow_stg_df['depreciationdepletionandamortization'], errors='coerce')
if(cash_flow_stg_df.dtypes['capitalexpenditures'] == 'O'):
    cash_flow_stg_df['capitalexpenditures'] = pd.to_numeric(cash_flow_stg_df['capitalexpenditures'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeinreceivables'] == 'O'):
    cash_flow_stg_df['changeinreceivables'] = pd.to_numeric(cash_flow_stg_df['changeinreceivables'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeininventory'] == 'O'):
    cash_flow_stg_df['changeininventory'] = pd.to_numeric(cash_flow_stg_df['changeininventory'], errors='coerce')
if(cash_flow_stg_df.dtypes['profitloss'] == 'O'):
    cash_flow_stg_df['profitloss'] = pd.to_numeric(cash_flow_stg_df['profitloss'], errors='coerce')
if(cash_flow_stg_df.dtypes['cashflowfrominvestment'] == 'O'):
    cash_flow_stg_df['cashflowfrominvestment'] = pd.to_numeric(cash_flow_stg_df['cashflowfrominvestment'], errors='coerce')
if(cash_flow_stg_df.dtypes['cashflowfromfinancing'] == 'O'):
    cash_flow_stg_df['cashflowfromfinancing'] = pd.to_numeric(cash_flow_stg_df['cashflowfromfinancing'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromrepaymentsofshorttermdebt'] == 'O'):
    cash_flow_stg_df['proceedsfromrepaymentsofshorttermdebt'] = pd.to_numeric(cash_flow_stg_df['proceedsfromrepaymentsofshorttermdebt'], errors='coerce')
if(cash_flow_stg_df.dtypes['paymentsforrepurchaseofcommonstock'] == 'O'):
    cash_flow_stg_df['paymentsforrepurchaseofcommonstock'] = pd.to_numeric(cash_flow_stg_df['paymentsforrepurchaseofcommonstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['paymentsforrepurchaseofequity'] == 'O'):
    cash_flow_stg_df['paymentsforrepurchaseofequity'] = pd.to_numeric(cash_flow_stg_df['paymentsforrepurchaseofequity'], errors='coerce')
if(cash_flow_stg_df.dtypes['paymentsforrepurchaseofpreferredstock'] == 'O'):
    cash_flow_stg_df['paymentsforrepurchaseofpreferredstock'] = pd.to_numeric(cash_flow_stg_df['paymentsforrepurchaseofpreferredstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['dividendpayout'] == 'O'):
    cash_flow_stg_df['dividendpayout'] = pd.to_numeric(cash_flow_stg_df['dividendpayout'], errors='coerce')
if(cash_flow_stg_df.dtypes['dividendpayoutcommonstock'] == 'O'):
    cash_flow_stg_df['dividendpayoutcommonstock'] = pd.to_numeric(cash_flow_stg_df['dividendpayoutcommonstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['dividendpayoutpreferredstock'] == 'O'):
    cash_flow_stg_df['dividendpayoutpreferredstock'] = pd.to_numeric(cash_flow_stg_df['dividendpayoutpreferredstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromissuanceofcommonstock'] == 'O'):
    cash_flow_stg_df['proceedsfromissuanceofcommonstock'] = pd.to_numeric(cash_flow_stg_df['proceedsfromissuanceofcommonstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromissuanceoflongtermdebtandcapitalsecuritiesnet'] == 'O'):
    cash_flow_stg_df['proceedsfromissuanceoflongtermdebtandcapitalsecuritiesnet'] = pd.to_numeric(cash_flow_stg_df['proceedsfromissuanceoflongtermdebtandcapitalsecuritiesnet'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromissuanceofpreferredstock'] == 'O'):
    cash_flow_stg_df['proceedsfromissuanceofpreferredstock'] = pd.to_numeric(cash_flow_stg_df['proceedsfromissuanceofpreferredstock'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromrepurchaseofequity'] == 'O'):
    cash_flow_stg_df['proceedsfromrepurchaseofequity'] = pd.to_numeric(cash_flow_stg_df['proceedsfromrepurchaseofequity'], errors='coerce')
if(cash_flow_stg_df.dtypes['proceedsfromsaleoftreasurystock'] == 'O'):
    cash_flow_stg_df['proceedsfromsaleoftreasurystock'] = pd.to_numeric(cash_flow_stg_df['proceedsfromsaleoftreasurystock'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeincashandcashequivalents'] == 'O'):
    cash_flow_stg_df['changeincashandcashequivalents'] = pd.to_numeric(cash_flow_stg_df['changeincashandcashequivalents'], errors='coerce')
if(cash_flow_stg_df.dtypes['changeinexchangerate'] == 'O'):
    cash_flow_stg_df['changeinexchangerate'] = pd.to_numeric(cash_flow_stg_df['changeinexchangerate'], errors='coerce')
if(cash_flow_stg_df.dtypes['netincome'] == 'O'):
    cash_flow_stg_df['netincome'] = pd.to_numeric(cash_flow_stg_df['netincome'], errors='coerce')

# %% [markdown]
# ### validar overview

# %%
overview_stg_df = overview_stg_df.replace('None','0')
if(overview_stg_df.dtypes['grossprofit'] == 'O'):
    overview_stg_df['grossprofit']  = pd.to_numeric(overview_stg_df['grossprofit'], errors='coerce')
if(overview_stg_df.dtypes['totalrevenue'] == 'O'):
    overview_stg_df['totalrevenue']  = pd.to_numeric(overview_stg_df['totalrevenue'], errors='coerce')
if(overview_stg_df.dtypes['costofrevenue'] == 'O'):
    overview_stg_df['costofrevenue']  = pd.to_numeric(overview_stg_df['costofrevenue'], errors='coerce')
if(overview_stg_df.dtypes['costofgoodsandservicessold'] == 'O'):
    overview_stg_df['costofgoodsandservicessold']  = pd.to_numeric(overview_stg_df['costofgoodsandservicessold'], errors='coerce')
if(overview_stg_df.dtypes['operatingincome'] == 'O'):
    overview_stg_df['operatingincome']  = pd.to_numeric(overview_stg_df['operatingincome'], errors='coerce')
if(overview_stg_df.dtypes['sellinggeneralandadministrative'] == 'O'):
    overview_stg_df['sellinggeneralandadministrative']  = pd.to_numeric(overview_stg_df['sellinggeneralandadministrative'], errors='coerce')
if(overview_stg_df.dtypes['researchanddevelopment'] == 'O'):
    overview_stg_df['researchanddevelopment']  = pd.to_numeric(overview_stg_df['researchanddevelopment'], errors='coerce')
if(overview_stg_df.dtypes['operatingexpenses'] == 'O'):
    overview_stg_df['operatingexpenses']  = pd.to_numeric(overview_stg_df['operatingexpenses'], errors='coerce')
if(overview_stg_df.dtypes['investmentincomenet'] == 'O'):
    overview_stg_df['investmentincomenet']  = pd.to_numeric(overview_stg_df['investmentincomenet'], errors='coerce')
if(overview_stg_df.dtypes['netinterestincome'] == 'O'):
    overview_stg_df['netinterestincome']  = pd.to_numeric(overview_stg_df['netinterestincome'], errors='coerce')
if(overview_stg_df.dtypes['interestincome'] == 'O'):
    overview_stg_df['interestincome']  = pd.to_numeric(overview_stg_df['interestincome'], errors='coerce')
if(overview_stg_df.dtypes['interestexpense'] == 'O'):
    overview_stg_df['interestexpense']  = pd.to_numeric(overview_stg_df['interestexpense'], errors='coerce')
if(overview_stg_df.dtypes['noninterestincome'] == 'O'):
    overview_stg_df['noninterestincome']  = pd.to_numeric(overview_stg_df['noninterestincome'], errors='coerce')
if(overview_stg_df.dtypes['othernonoperatingincome'] == 'O'):
    overview_stg_df['othernonoperatingincome']  = pd.to_numeric(overview_stg_df['othernonoperatingincome'], errors='coerce')
if(overview_stg_df.dtypes['depreciation'] == 'O'):
    overview_stg_df['depreciation']  = pd.to_numeric(overview_stg_df['depreciation'], errors='coerce')
if(overview_stg_df.dtypes['depreciationandamortization'] == 'O'):
    overview_stg_df['depreciationandamortization']  = pd.to_numeric(overview_stg_df['depreciationandamortization'], errors='coerce')
if(overview_stg_df.dtypes['incomebeforetax'] == 'O'):
    overview_stg_df['incomebeforetax']  = pd.to_numeric(overview_stg_df['incomebeforetax'], errors='coerce')
if(overview_stg_df.dtypes['incometaxexpense'] == 'O'):
    overview_stg_df['incometaxexpense']  = pd.to_numeric(overview_stg_df['incometaxexpense'], errors='coerce')
if(overview_stg_df.dtypes['interestanddebtexpense'] == 'O'):
    overview_stg_df['interestanddebtexpense']  = pd.to_numeric(overview_stg_df['interestanddebtexpense'], errors='coerce')
if(overview_stg_df.dtypes['netincomefromcontinuingoperations'] == 'O'):
    overview_stg_df['netincomefromcontinuingoperations']  = pd.to_numeric(overview_stg_df['netincomefromcontinuingoperations'], errors='coerce')
if(overview_stg_df.dtypes['comprehensiveincomenetoftax'] == 'O'):
    overview_stg_df['comprehensiveincomenetoftax']  = pd.to_numeric(overview_stg_df['comprehensiveincomenetoftax'], errors='coerce')
if(overview_stg_df.dtypes['ebit'] == 'O'):
    overview_stg_df['ebit']  = pd.to_numeric(overview_stg_df['ebit'], errors='coerce')
if(overview_stg_df.dtypes['ebitda'] == 'O'):
    overview_stg_df['ebitda']  = pd.to_numeric(overview_stg_df['ebitda'], errors='coerce')
if(overview_stg_df.dtypes['netincome'] == 'O'):
    overview_stg_df['netincome']  = pd.to_numeric(overview_stg_df['netincome'], errors='coerce')

# %% [markdown]
# ### validar income statement

# %%
if(income_statement_stg_df.dtypes['grossprofit'] == 'O'):
    income_statement_stg_df['grossprofit']   = pd.to_numeric(income_statement_stg_df['grossprofit'], errors='coerce')
if(income_statement_stg_df.dtypes['totalrevenue'] == 'O'):
    income_statement_stg_df['totalrevenue']   = pd.to_numeric(income_statement_stg_df['totalrevenue'], errors='coerce')
if(income_statement_stg_df.dtypes['costofrevenue'] == 'O'):
    income_statement_stg_df['costofrevenue']   = pd.to_numeric(income_statement_stg_df['costofrevenue'], errors='coerce')
if(income_statement_stg_df.dtypes['costofgoodsandservicessold'] == 'O'):
    income_statement_stg_df['costofgoodsandservicessold']   = pd.to_numeric(income_statement_stg_df['costofgoodsandservicessold'], errors='coerce')
if(income_statement_stg_df.dtypes['operatingincome'] == 'O'):
    income_statement_stg_df['operatingincome']   = pd.to_numeric(income_statement_stg_df['operatingincome'], errors='coerce')
if(income_statement_stg_df.dtypes['sellinggeneralandadministrative'] == 'O'):
    income_statement_stg_df['sellinggeneralandadministrative']   = pd.to_numeric(income_statement_stg_df['sellinggeneralandadministrative'], errors='coerce')
if(income_statement_stg_df.dtypes['researchanddevelopment'] == 'O'):
    income_statement_stg_df['researchanddevelopment']   = pd.to_numeric(income_statement_stg_df['researchanddevelopment'], errors='coerce')
if(income_statement_stg_df.dtypes['operatingexpenses'] == 'O'):
    income_statement_stg_df['operatingexpenses']   = pd.to_numeric(income_statement_stg_df['operatingexpenses'], errors='coerce')
if(income_statement_stg_df.dtypes['investmentincomenet'] == 'O'):
    income_statement_stg_df['investmentincomenet']   = pd.to_numeric(income_statement_stg_df['investmentincomenet'], errors='coerce')
if(income_statement_stg_df.dtypes['netinterestincome'] == 'O'):
    income_statement_stg_df['netinterestincome']   = pd.to_numeric(income_statement_stg_df['netinterestincome'], errors='coerce')
if(income_statement_stg_df.dtypes['interestincome'] == 'O'):
    income_statement_stg_df['interestincome']   = pd.to_numeric(income_statement_stg_df['interestincome'], errors='coerce')
if(income_statement_stg_df.dtypes['interestexpense'] == 'O'):
    income_statement_stg_df['interestexpense']   = pd.to_numeric(income_statement_stg_df['interestexpense'], errors='coerce')
if(income_statement_stg_df.dtypes['noninterestincome'] == 'O'):
    income_statement_stg_df['noninterestincome']   = pd.to_numeric(income_statement_stg_df['noninterestincome'], errors='coerce')
if(income_statement_stg_df.dtypes['othernonoperatingincome'] == 'O'):
    income_statement_stg_df['othernonoperatingincome']   = pd.to_numeric(income_statement_stg_df['othernonoperatingincome'], errors='coerce')
if(income_statement_stg_df.dtypes['depreciation'] == 'O'):
    income_statement_stg_df['depreciation']   = pd.to_numeric(income_statement_stg_df['depreciation'], errors='coerce')
if(income_statement_stg_df.dtypes['depreciationandamortization'] == 'O'):
    income_statement_stg_df['depreciationandamortization']   = pd.to_numeric(income_statement_stg_df['depreciationandamortization'], errors='coerce')
if(income_statement_stg_df.dtypes['incomebeforetax'] == 'O'):
    income_statement_stg_df['incomebeforetax']   = pd.to_numeric(income_statement_stg_df['incomebeforetax'], errors='coerce')
if(income_statement_stg_df.dtypes['incometaxexpense'] == 'O'):
    income_statement_stg_df['incometaxexpense']   = pd.to_numeric(income_statement_stg_df['incometaxexpense'], errors='coerce')
if(income_statement_stg_df.dtypes['interestanddebtexpense'] == 'O'):
    income_statement_stg_df['interestanddebtexpense']   = pd.to_numeric(income_statement_stg_df['interestanddebtexpense'], errors='coerce')
if(income_statement_stg_df.dtypes['netincomefromcontinuingoperations'] == 'O'):
    income_statement_stg_df['netincomefromcontinuingoperations']   = pd.to_numeric(income_statement_stg_df['netincomefromcontinuingoperations'], errors='coerce')
if(income_statement_stg_df.dtypes['comprehensiveincomenetoftax'] == 'O'):
    income_statement_stg_df['comprehensiveincomenetoftax']   = pd.to_numeric(income_statement_stg_df['comprehensiveincomenetoftax'], errors='coerce')
if(income_statement_stg_df.dtypes['ebit'] == 'O'):
    income_statement_stg_df['ebit']   = pd.to_numeric(income_statement_stg_df['ebit'], errors='coerce')
if(income_statement_stg_df.dtypes['ebitda'] == 'O'):
    income_statement_stg_df['ebitda']   = pd.to_numeric(income_statement_stg_df['ebitda'], errors='coerce')
if(income_statement_stg_df.dtypes['netincome'] == 'O'):
    income_statement_stg_df['netincome']   = pd.to_numeric(income_statement_stg_df['netincome'], errors='coerce')

# %% [markdown]
# ### validar retail

# %%
retail_stg_df = retail_stg_df.replace('None','0')
if(retail_stg_df.dtypes['value'] == 'O'):
    retail_stg_df['value']  = pd.to_numeric(retail_stg_df['value'], errors='coerce')

# %% [markdown]
# ### validar inflation

# %%
inflation_stg_df = inflation_stg_df.replace('None','0')
if(inflation_stg_df.dtypes['value'] == 'O'):
    inflation_stg_df['value']  = pd.to_numeric(inflation_stg_df['value'], errors='coerce')

# %%
retail_stg_df
# Out:
#       id        date     value                                name interval  \
# 0      1  2025-01-01  577230.0  Advance Retail Sales: Retail Trade  monthly
# 1      2  2024-12-01  702255.0  Advance Retail Sales: Retail Trade  monthly
# 2      3  2024-11-01  641949.0  Advance Retail Sales: Retail Trade  monthly
# 3      4  2024-10-01  633013.0  Advance Retail Sales: Retail Trade  monthly
# 4      5  2024-09-01  589777.0  Advance Retail Sales: Retail Trade  monthly
# ..   ...         ...       ...                                 ...      ...
# 789  790  1992-05-01  152420.0  Advance Retail Sales: Retail Trade  monthly
# 790  791  1992-04-01  147175.0  Advance Retail Sales: Retail Trade  monthly
# 791  792  1992-03-01  142488.0  Advance Retail Sales: Retail Trade  monthly
# 792  793  1992-02-01  131244.0  Advance Retail Sales: Retail Trade  monthly
# 793  794  1992-01-01  130683.0  Advance Retail Sales: Retail Trade  monthly
#
#                     unit symbol    loaddate
# ...

# %% [markdown]
# ### Cargando DWH

# %%
dwh_dataframes = [
    (inflation_stg_df, 'dwh','inflation'),
    (cpi_stg_df,'dwh', 'cpi'),
    (cash_flow_stg_df,'dwh', 'cash_flow'),
    (overview_stg_df,'dwh', 'overview'),
    (income_statement_stg_df,'dwh', 'income_statement'),
    (balance_stg_df,'dwh', 'balance'),
    (retail_stg_df,'dwh', 'retail')    
]

def truncar_tablas_dwh():
    try:
        conexion = get_conexion()
        cursor = conexion.cursor()
        
        truncate_script = ""
        for df, schema, tabla in dwh_dataframes:
            truncate_script += f'truncate table {schema}.{tabla} restart identity cascade;'

        cursor.execute(truncate_script)
        conexion.commit()
    except psycopg2.Error as e:
        add_error_logs(f"Error en la operación de truncado: {e}")
        if conexion:
            conexion.rollback()
    finally:
        if cursor:
            cursor.close()
        if conexion:
            conexion.close()

def cargar_dwh():
    columnas = ['descripcion', 'etapa', 'fecha', 'entidad', 'estatus']
    log_results_df = pd.DataFrame(columns=columnas)
    
    try:
        conexion = get_conexion()
        cursor = conexion.cursor()

        for df, schema, tabla in dwh_dataframes:
            for i, row in df.iterrows():
                columns = ', '.join(df.columns)
                values = ', '.join([f"'{str(value)}'" if value is not None else "NULL" for value in row])
                query = f"INSERT INTO {schema}.{tabla} ({columns}) VALUES ({values})"
                cursor.execute(query)
            print(f'{schema}.{tabla}')
            conexion.commit()
            cargar_logs(cursor, conexion, schema, tabla)                               

        cursor.close()
        conexion.close()
        
    except Exception as e:
        add_error_logs(f"Error al cargar los DataFrames: {e}")        
        if conexion:
            conexion.rollback()
        if cursor:
            cursor.close()
        if conexion:
            conexion.close()

# %%
error_logs =[]
truncar_tablas_dwh()

# %%
cargar_dwh()
# Out:
# dwh.inflation
# dwh.cpi
# dwh.cash_flow
# dwh.overview
# dwh.income_statement
# dwh.balance
# dwh.retail

# %%
error_logs
# Out:
# []

# %%
balance_stg_df.dtypes
# Out:
# id                                          int64
# fiscaldateending                           object
# reportedcurrency                           object
# totalassets                                 int64
# totalcurrentassets                          int64
# cashandcashequivalentsatcarryingvalue       int64
# cashandshortterminvestments                 int64
# inventory                                   int64
# currentnetreceivables                       int64
# totalnoncurrentassets                       int64
# propertyplantequipment                      int64
# accumulateddepreciationamortizationppe      int64
# intangibleassets                            int64
# intangibleassetsexcludinggoodwill           int64
# goodwill                                    int64
# investments                                 int64
# longterminvestments                       float64
# shortterminvestments                      float64
# othercurrentassets                          int64
# ...
